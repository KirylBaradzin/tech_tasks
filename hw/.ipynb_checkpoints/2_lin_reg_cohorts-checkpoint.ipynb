# %%
#import libs
import pandas as pd
from sklearn import metrics
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import statsmodels.api as sm
import scipy as sc
from statsmodels.graphics.regressionplots import plot_leverage_resid2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Read a data

# %%
#importing prepared data - daily cohorts with counts and ACQ_BEDVALUE Mean by stay value - I decided to transform this task to Cohort LTV prediction
initial_dataframe=pd.read_csv('cohorts_7.csv')

# %%
initial_dataframe.drop(['Unnamed: 0','ACQ_BOOKEDDATE'],axis=1,inplace=True)

# %%
initial_dataframe
# Out:
#     ACQ_BEDVALUE_Mean  Customers_count  LIFETIME_BEDVALUE_mean  \
# 0            569.1836             1228              10452.7843
# 1            578.5431             1169               9272.1131
# 2            595.4815             1345               8883.1179
# 3            579.2841             1420               8948.0448
# 4            596.2268             1470               8711.0281
# ..                ...              ...                     ...
# 88           490.9121              925               7221.9736
# 89           515.3059              948               7246.0550
# 90           557.1752              911               9124.1932
# 91           519.6260              882               7254.3301
# 92           500.1201              844               7563.6970
#
#     ACQ_BEDVALUE/Domestic/DESKTOP/1-2 Nights/  \
# 0                                      0.4922
# 1                                      0.5732
# 2                                      0.5386
# 3                                      0.5804
# 4                                      0.5361
# ..                                        ...
# 88                                     0.6552
# 89                                     0.6727
# 90                                     0.5697
# 91                                     0.5682
# 92                                     0.5458
#
#     ACQ_BEDVALUE/Domestic/DESKTOP/3-4 Nights/  \
# 0                                      1.4406
# 1                                      1.1698
# 2                                      1.0488
# 3                                      0.7932
# 4                                      1.2738
# ..                                        ...
# 88                                     1.4776
# 89                                     1.7472
# 90                                     1.2183
# 91                                     1.0790
# 92                                     1.8465
#
#     ACQ_BEDVALUE/Domestic/DESKTOP/5-6 Nights/  \
# 0                                      1.9236
# 1                                      1.5185
# 2                                      1.7896
# 3                                      1.1125
# 4                                      2.0506
# ..                                        ...
# 88                                     1.2312
# 89                                     0.9941
# 90                                     2.4255
# 91                                     0.9673
# 92                                     0.5684
#
#     ACQ_BEDVALUE/Domestic/DESKTOP/7+ Nights/  \
# 0                                     2.1848
# 1                                     2.8058
# 2                                     2.5911
# 3                                     3.7431
# 4                                     2.3212
# ..                                       ...
# 88                                    2.1251
# 89                                    1.3221
# 90                                    4.0003
# 91                                    2.5067
# 92                                    2.0217
#
#     ACQ_BEDVALUE/Domestic/MOBILE/1-2 Nights/  \
# 0                                     0.4969
# 1                                     0.3698
# 2                                     0.3994
# 3                                     0.3392
# 4                                     0.4298
# ..                                       ...
# 88                                    0.4939
# 89                                    0.5659
# 90                                    0.4634
# 91                                    0.4336
# 92                                    0.4363
#
#     ACQ_BEDVALUE/Domestic/MOBILE/3-4 Nights/  \
# 0                                     0.9032
# 1                                     1.1248
# 2                                     0.8947
# 3                                     1.0516
# 4                                     0.9121
# ..                                       ...
# 88                                    1.0070
# 89                                    0.8776
# 90                                    1.2379
# 91                                    1.0791
# 92                                    1.2743
#
#     ACQ_BEDVALUE/Domestic/MOBILE/5-6 Nights/  ...  \
# 0                                     1.4853  ...
# 1                                     0.3182  ...
# 2                                     1.0839  ...
# 3                                     1.2877  ...
# 4                                     0.9683  ...
# ..                                       ...  ...
# 88                                    1.3927  ...
# 89                                    1.8396  ...
# 90                                    1.8900  ...
# 91                                    1.4536  ...
# 92                                    1.0151  ...
#
#     CUSTOMER_ID/Long Haul/MOBILE/5-6 Nights/  \
# 0                                     0.0024
# 1                                     0.0051
# 2                                     0.0045
# 3                                     0.0063
# 4                                     0.0048
# ..                                       ...
# 88                                    0.0065
# 89                                    0.0042
# 90                                    0.0044
# 91                                    0.0034
# 92                                    0.0047
#
#     CUSTOMER_ID/Long Haul/MOBILE/7+ Nights/  \
# 0                                    0.0049
# 1                                    0.0051
# 2                                    0.0030
# 3                                    0.0063
# 4                                    0.0048
# ..                                      ...
# 88                                   0.0022
# 89                                   0.0074
# 90                                   0.0033
# 91                                   0.0034
# 92                                   0.0024
#
#     CUSTOMER_ID/Short Haul/DESKTOP/1-2 Nights/  \
# 0                                       0.1474
# 1                                       0.1155
# 2                                       0.1651
# 3                                       0.1831
# 4                                       0.1660
# ..                                         ...
# 88                                      0.1524
# 89                                      0.1593
# 90                                      0.1778
# 91                                      0.1542
# 92                                      0.1410
#
#     CUSTOMER_ID/Short Haul/DESKTOP/3-4 Nights/  \
# 0                                       0.0774
# 1                                       0.0855
# 2                                       0.0818
# 3                                       0.0789
# 4                                       0.0844
# ..                                         ...
# 88                                      0.0768
# 89                                      0.0675
# 90                                      0.0615
# 91                                      0.0737
# 92                                      0.0806
#
#     CUSTOMER_ID/Short Haul/DESKTOP/5-6 Nights/  \
# 0                                       0.0147
# 1                                       0.0205
# 2                                       0.0126
# 3                                       0.0141
# 4                                       0.0211
# ..                                         ...
# 88                                      0.0130
# 89                                      0.0232
# 90                                      0.0154
# 91                                      0.0249
# 92                                      0.0249
#
#     CUSTOMER_ID/Short Haul/DESKTOP/7+ Nights/  \
# 0                                      0.0098
# 1                                      0.0120
# 2                                      0.0082
# 3                                      0.0134
# 4                                      0.0129
# ..                                        ...
# 88                                     0.0173
# 89                                     0.0074
# 90                                     0.0220
# 91                                     0.0068
# 92                                     0.0118
#
#     CUSTOMER_ID/Short Haul/MOBILE/1-2 Nights/  \
# 0                                      0.0920
# 1                                      0.1326
# 2                                      0.0967
# 3                                      0.0880
# 4                                      0.1027
# ..                                        ...
# 88                                     0.1622
# 89                                     0.1234
# 90                                     0.1087
# 91                                     0.1349
# 92                                     0.1410
#
#     CUSTOMER_ID/Short Haul/MOBILE/3-4 Nights/  \
# 0                                      0.0358
# 1                                      0.0325
# 2                                      0.0349
# 3                                      0.0310
# 4                                      0.0279
# ..                                        ...
# 88                                     0.0314
# 89                                     0.0285
# 90                                     0.0362
# 91                                     0.0397
# 92                                     0.0284
#
#     CUSTOMER_ID/Short Haul/MOBILE/5-6 Nights/  \
# 0                                      0.0081
# 1                                      0.0009
# 2                                      0.0059
# 3                                      0.0042
# 4                                      0.0048
# ..                                        ...
# 88                                     0.0043
# 89                                     0.0095
# 90                                     0.0033
# 91                                     0.0034
# 92                                     0.0036
#
#     CUSTOMER_ID/Short Haul/MOBILE/7+ Nights/
# 0                                     0.0041
# 1                                     0.0017
# 2                                     0.0067
# 3                                     0.0021
# 4                                     0.0034
# ..                                       ...
# 88                                    0.0022
# 89                                    0.0021
# 90                                    0.0055
# 91                                    0.0057
# 92                                    0.0036
#
# [93 rows x 51 columns]

# %%
initial_dataframe.describe()
# Out:
#        ACQ_BEDVALUE_Mean  Customers_count  LIFETIME_BEDVALUE_mean  \
# count          93.000000        93.000000               93.000000
# mean          531.075639      1178.301075             8131.442433
# std            28.601066       154.113932              713.007321
# min           459.300900       822.000000             6706.070100
# 25%           511.213600      1072.000000             7574.979900
# 50%           529.819400      1181.000000             8162.706500
# 75%           548.436400      1295.000000             8613.832600
# max           596.226800      1472.000000            10452.784300
#
#        ACQ_BEDVALUE/Domestic/DESKTOP/1-2 Nights/  \
# count                                  93.000000
# mean                                    0.576603
# std                                     0.066383
# min                                     0.402500
# 25%                                     0.537300
# 50%                                     0.572100
# 75%                                     0.621300
# max                                     0.731200
#
#        ACQ_BEDVALUE/Domestic/DESKTOP/3-4 Nights/  \
# count                                  93.000000
# mean                                    1.286774
# std                                     0.303917
# min                                     0.706700
# 25%                                     1.067500
# 50%                                     1.243800
# 75%                                     1.440600
# max                                     2.096200
#
#        ACQ_BEDVALUE/Domestic/DESKTOP/5-6 Nights/  \
# count                                  93.000000
# mean                                    1.936112
# std                                     1.165107
# min                                     0.492400
# 25%                                     1.305600
# 50%                                     1.758400
# 75%                                     2.392100
# max                                    10.167600
#
#        ACQ_BEDVALUE/Domestic/DESKTOP/7+ Nights/  \
# count                                 93.000000
# mean                                   2.593322
# std                                    1.406628
# min                                    0.000000
# 25%                                    1.713600
# 50%                                    2.301400
# 75%                                    3.290400
# max                                    8.693800
#
#        ACQ_BEDVALUE/Domestic/MOBILE/1-2 Nights/  \
# count                                 93.000000
# mean                                   0.466623
# std                                    0.056941
# min                                    0.339200
# 25%                                    0.422600
# 50%                                    0.469200
# 75%                                    0.502600
# max                                    0.614500
#
#        ACQ_BEDVALUE/Domestic/MOBILE/3-4 Nights/  \
# count                                 93.000000
# mean                                   1.063269
# std                                    0.192277
# min                                    0.527100
# 25%                                    0.923100
# 50%                                    1.058100
# 75%                                    1.154900
# max                                    1.626600
#
#        ACQ_BEDVALUE/Domestic/MOBILE/5-6 Nights/  ...  \
# count                                 93.000000  ...
# mean                                   1.588917  ...
# std                                    0.635026  ...
# min                                    0.318200  ...
# 25%                                    1.183300  ...
# 50%                                    1.561800  ...
# 75%                                    1.838900  ...
# max                                    3.234300  ...
#
#        CUSTOMER_ID/Long Haul/MOBILE/5-6 Nights/  \
# count                                 93.000000
# mean                                   0.004142
# std                                    0.001488
# min                                    0.000900
# 25%                                    0.003100
# 50%                                    0.004400
# 75%                                    0.005100
# max                                    0.007000
#
#        CUSTOMER_ID/Long Haul/MOBILE/7+ Nights/  \
# count                                93.000000
# mean                                  0.003469
# std                                   0.001841
# min                                   0.000000
# 25%                                   0.002400
# 50%                                   0.003400
# 75%                                   0.004800
# max                                   0.008100
#
#        CUSTOMER_ID/Short Haul/DESKTOP/1-2 Nights/  \
# count                                   93.000000
# mean                                     0.166474
# std                                      0.016876
# min                                      0.115500
# 25%                                      0.154500
# 50%                                      0.166700
# 75%                                      0.178200
# max                                      0.209100
#
#        CUSTOMER_ID/Short Haul/DESKTOP/3-4 Nights/  \
# count                                   93.000000
# mean                                     0.073739
# std                                      0.008685
# min                                      0.052700
# 25%                                      0.067100
# 50%                                      0.074500
# 75%                                      0.080600
# max                                      0.093500
#
#        CUSTOMER_ID/Short Haul/DESKTOP/5-6 Nights/  \
# count                                   93.000000
# mean                                     0.016403
# std                                      0.003892
# min                                      0.006400
# 25%                                      0.013300
# 50%                                      0.016700
# 75%                                      0.018800
# max                                      0.024900
#
#        CUSTOMER_ID/Short Haul/DESKTOP/7+ Nights/  \
# count                                  93.000000
# mean                                    0.010427
# std                                     0.003336
# min                                     0.004000
# 25%                                     0.008200
# 50%                                     0.010200
# 75%                                     0.012700
# max                                     0.022000
#
#        CUSTOMER_ID/Short Haul/MOBILE/1-2 Nights/  \
# count                                  93.000000
# mean                                    0.127985
# std                                     0.020232
# min                                     0.088000
# 25%                                     0.113000
# 50%                                     0.127400
# 75%                                     0.140200
# max                                     0.176500
#
#        CUSTOMER_ID/Short Haul/MOBILE/3-4 Nights/  \
# count                                  93.000000
# mean                                    0.036963
# std                                     0.006847
# min                                     0.020800
# 25%                                     0.032800
# 50%                                     0.035900
# 75%                                     0.041500
# max                                     0.057500
#
#        CUSTOMER_ID/Short Haul/MOBILE/5-6 Nights/  \
# count                                  93.000000
# mean                                    0.006500
# std                                     0.002164
# min                                     0.000900
# 25%                                     0.005100
# 50%                                     0.006300
# 75%                                     0.008100
# max                                     0.012100
#
#        CUSTOMER_ID/Short Haul/MOBILE/7+ Nights/
# count                                 93.000000
# mean                                   0.004156
# std                                    0.002000
# min                                    0.000000
# 25%                                    0.002700
# 50%                                    0.003900
# 75%                                    0.005500
# max                                    0.010500
#
# [8 rows x 51 columns]

# %%
#Utilizing StandardScaler to help model converge
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()
data = pd.DataFrame(scale.fit_transform(initial_dataframe),columns = initial_dataframe.columns)

# %%
data
# Out:
#     ACQ_BEDVALUE_Mean  Customers_count  LIFETIME_BEDVALUE_mean  \
# 0            1.339618         0.324230                3.273352
# 1            1.668635        -0.060679                1.608473
# 2            2.264075         1.087523                1.059947
# 3            1.694684         1.576814                1.151501
# 4            2.290274         1.903007                0.817281
# ..                ...              ...                     ...
# 88          -1.411878        -1.652505               -1.282453
# 89          -0.554357        -1.502456               -1.248495
# 90           0.917484        -1.743839                1.399890
# 91          -0.402492        -1.933031               -1.236827
# 92          -1.088187        -2.180939               -0.800585
#
#     ACQ_BEDVALUE/Domestic/DESKTOP/1-2 Nights/  \
# 0                                   -1.278357
# 1                                   -0.051545
# 2                                   -0.575590
# 3                                    0.057505
# 4                                   -0.613455
# ..                                        ...
# 88                                   1.190413
# 89                                   1.455465
# 90                                  -0.104555
# 91                                  -0.127274
# 92                                  -0.466540
#
#     ACQ_BEDVALUE/Domestic/DESKTOP/3-4 Nights/  \
# 0                                    0.508888
# 1                                   -0.386975
# 2                                   -0.787269
# 3                                   -1.632848
# 4                                   -0.042921
# ..                                        ...
# 88                                   0.631292
# 89                                   1.523186
# 90                                  -0.226527
# 91                                  -0.687361
# 92                                   1.851691
#
#     ACQ_BEDVALUE/Domestic/DESKTOP/5-6 Nights/  \
# 0                                   -0.010797
# 1                                   -0.360375
# 2                                   -0.126431
# 3                                   -0.710729
# 4                                    0.098797
# ..                                        ...
# 88                                  -0.608298
# 89                                  -0.812902
# 90                                   0.422314
# 91                                  -0.836029
# 92                                  -1.180256
#
#     ACQ_BEDVALUE/Domestic/DESKTOP/7+ Nights/  \
# 0                                  -0.292000
# 1                                   0.151874
# 2                                  -0.001588
# 3                                   0.821831
# 4                                  -0.194505
# ..                                       ...
# 88                                 -0.334672
# 89                                 -0.908635
# 90                                  1.005671
# 91                                 -0.061915
# 92                                 -0.408580
#
#     ACQ_BEDVALUE/Domestic/MOBILE/1-2 Nights/  \
# 0                                   0.534612
# 1                                  -1.709608
# 2                                  -1.186957
# 3                                  -2.249916
# 4                                  -0.650181
# ..                                       ...
# 88                                  0.481641
# 89                                  1.752953
# 90                                 -0.056901
# 91                                 -0.583084
# 92                                 -0.535409
#
#     ACQ_BEDVALUE/Domestic/MOBILE/3-4 Nights/  \
# 0                                  -0.837002
# 1                                   0.321747
# 2                                  -0.881449
# 3                                  -0.061016
# 4                                  -0.790464
# ..                                       ...
# 88                                 -0.294230
# 89                                 -0.970865
# 90                                  0.913149
# 91                                  0.082781
# 92                                  1.103485
#
#     ACQ_BEDVALUE/Domestic/MOBILE/5-6 Nights/  ...  \
# 0                                  -0.164054  ...
# 1                                  -2.011894  ...
# 2                                  -0.799581  ...
# 3                                  -0.476910  ...
# 4                                  -0.982607  ...
# ..                                       ...  ...
# 88                                 -0.310666  ...
# 89                                  0.396900  ...
# 90                                  0.476697  ...
# 91                                 -0.214244  ...
# 92                                 -0.908510  ...
#
#     CUSTOMER_ID/Long Haul/MOBILE/5-6 Nights/  \
# 0                                  -1.176986
# 1                                   0.647342
# 2                                   0.241936
# 3                                   1.458154
# 4                                   0.444639
# ..                                       ...
# 88                                  1.593290
# 89                                  0.039233
# 90                                  0.174368
# 91                                 -0.501309
# 92                                  0.377071
#
#     CUSTOMER_ID/Long Haul/MOBILE/7+ Nights/  \
# 0                                  0.781425
# 1                                  0.890625
# 2                                 -0.255974
# 3                                  1.545825
# 4                                  0.726825
# ..                                      ...
# 88                                -0.692774
# 89                                 2.146424
# 90                                -0.092174
# 91                                -0.037574
# 92                                -0.583574
#
#     CUSTOMER_ID/Short Haul/DESKTOP/1-2 Nights/  \
# 0                                    -1.136366
# 1                                    -3.036843
# 2                                    -0.081869
# 3                                     0.990500
# 4                                    -0.028251
# ..                                         ...
# 88                                   -0.838485
# 89                                   -0.427410
# 90                                    0.674747
# 91                                   -0.731248
# 92                                   -1.517653
#
#     CUSTOMER_ID/Short Haul/DESKTOP/3-4 Nights/  \
# 0                                     0.423871
# 1                                     1.361615
# 2                                     0.933263
# 3                                     0.597527
# 4                                     1.234267
# ..                                         ...
# 88                                    0.354408
# 89                                   -0.722261
# 90                                   -1.416886
# 91                                   -0.004481
# 92                                    0.794337
#
#     CUSTOMER_ID/Short Haul/DESKTOP/5-6 Nights/  \
# 0                                    -0.440047
# 1                                     1.058447
# 2                                    -0.982606
# 3                                    -0.595064
# 4                                     1.213464
# ..                                         ...
# 88                                   -0.879261
# 89                                    1.756022
# 90                                   -0.259195
# 91                                    2.195236
# 92                                    2.195236
#
#     CUSTOMER_ID/Short Haul/DESKTOP/7+ Nights/  \
# 0                                   -0.188914
# 1                                    0.474067
# 2                                   -0.671082
# 3                                    0.895964
# 4                                    0.745286
# ..                                        ...
# 88                                   2.071248
# 89                                  -0.912165
# 90                                   3.487615
# 91                                  -1.092978
# 92                                   0.413796
#
#     CUSTOMER_ID/Short Haul/MOBILE/1-2 Nights/  \
# 0                                   -1.788217
# 1                                    0.229338
# 2                                   -1.554658
# 3                                   -1.986991
# 4                                   -1.256497
# ..                                        ...
# 88                                   1.700265
# 89                                  -0.227842
# 90                                  -0.958336
# 91                                   0.343633
# 92                                   0.646763
#
#     CUSTOMER_ID/Short Haul/MOBILE/3-4 Nights/  \
# 0                                   -0.170831
# 1                                   -0.655379
# 2                                   -0.302981
# 3                                   -0.875628
# 4                                   -1.330809
# ..                                        ...
# 88                                  -0.816895
# 89                                  -1.242710
# 90                                  -0.112098
# 91                                   0.401816
# 92                                  -1.257393
#
#     CUSTOMER_ID/Short Haul/MOBILE/5-6 Nights/  \
# 0                                    0.743229
# 1                                   -2.601303
# 2                                   -0.278711
# 3                                   -1.068392
# 4                                   -0.789681
# ..                                        ...
# 88                                  -1.021940
# 89                                   1.393555
# 90                                  -1.486459
# 91                                  -1.440007
# 92                                  -1.347103
#
#     CUSTOMER_ID/Short Haul/MOBILE/7+ Nights/
# 0                                  -0.028103
# 1                                  -1.234362
# 2                                   1.278678
# 3                                  -1.033319
# 4                                  -0.379929
# ..                                       ...
# 88                                 -0.983058
# 89                                 -1.033319
# 90                                  0.675549
# 91                                  0.776070
# 92                                 -0.279407
#
# [93 rows x 51 columns]

# %%
cols_dict = {}
k=0
for i in initial_dataframe.columns:
    if i == 'LIFETIME_BEDVALUE_mean':
        pass
    else:
        k+=1
        new_col_name = 'x'+str(k)
        cols_dict.update({new_col_name:i})
        data = data.rename({i : new_col_name}, axis=1)

# %%
cols_dict.keys()
# Out:
# dict_keys(['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x40', 'x41', 'x42', 'x43', 'x44', 'x45', 'x46', 'x47', 'x48', 'x49', 'x50'])

# %% [markdown]
# # Let's look at the dependences of the variables on each other and the corresponding histograms

# %%
sns.pairplot(data)

# %%
from IPython.display import Image
import seaborn as sns
import matplotlib.pyplot as plt 

sns_plot = sns.pairplot(data, size=2.0)
sns_plot.savefig("pairplot.png")

plt.clf() # Clean parirplot figure from sns 
Image(filename='pairplot.png') # Show pairplot as image

# %%
Y = data['LIFETIME_BEDVALUE_mean']
X = data.drop('LIFETIME_BEDVALUE_mean',axis=1)

# %% [markdown]
# ### Let's build the simplest linear regression model on the available data.

# %% [markdown]
# # Model #1: The simplest linear model.

# %%
model1 = sm.OLS(Y,sm.add_constant(X))
fitted = model1.fit()
print (fitted.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     LIFETIME_BEDVALUE_mean   R-squared:                       0.783
# Model:                                OLS   Adj. R-squared:                  0.524
# Method:                     Least Squares   F-statistic:                     3.025
# Date:                    Mon, 02 May 2022   Prob (F-statistic):           0.000179
# Time:                            11:51:00   Log-Likelihood:                -60.984
# No. Observations:                      93   AIC:                             224.0
# Df Residuals:                          42   BIC:                             353.1
# Df Model:                              50
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.962e-15      0.072  -9.68e-14      1.000      -0.145       0.145
# x1             0.1647      0.155      1.065      0.293      -0.147       0.477
# x2             0.2047      0.165      1.241      0.221      -0.128       0.537
# x3            -0.1433      0.124     -1.155      0.255      -0.394       0.107
# x4            -0.0727      0.146     -0.498      0.621      -0.367       0.222
# x5             0.0666      0.095      0.698      0.489      -0.126       0.259
# x6            -0.0568      0.121     -0.469      0.642      -0.301       0.188
# x7            -0.0862      0.140     -0.615      0.542      -0.369       0.196
# x8            -0.0732      0.118     -0.619      0.539      -0.312       0.165
# x9             0.0031      0.108      0.028      0.978      -0.216       0.222
# x10           -0.0240      0.121     -0.198      0.844      -0.269       0.221
# x11           -0.1182      0.119     -0.997      0.324      -0.357       0.121
# x12           -0.0967      0.168     -0.575      0.568      -0.436       0.243
# x13           -0.1424      0.132     -1.079      0.287      -0.409       0.124
# x14           -0.1386      0.132     -1.046      0.301      -0.406       0.129
# x15           -0.0406      0.125     -0.325      0.746      -0.292       0.211
# x16           -0.0966      0.120     -0.803      0.427      -0.339       0.146
# x17           -0.0178      0.106     -0.168      0.867      -0.231       0.196
# x18           -0.1828      0.106     -1.723      0.092      -0.397       0.031
# x19           -0.0430      0.158     -0.272      0.787      -0.362       0.276
# x20           -0.1397      0.152     -0.922      0.362      -0.446       0.166
# x21           -0.1715      0.124     -1.387      0.173      -0.421       0.078
# x22           -0.0402      0.150     -0.268      0.790      -0.343       0.263
# x23           -0.0171      0.107     -0.160      0.874      -0.233       0.199
# x24           -0.0593      0.132     -0.450      0.655      -0.325       0.207
# x25           -0.0027      0.120     -0.022      0.982      -0.245       0.240
# x26            0.0910      0.107      0.854      0.398      -0.124       0.306
# x27            7.9636      9.060      0.879      0.384     -10.320      26.247
# x28            3.5078      4.247      0.826      0.413      -5.062      12.078
# x29            1.5924      1.714      0.929      0.358      -1.867       5.051
# x30            1.2207      1.417      0.862      0.394      -1.638       4.080
# x31           12.5769     14.193      0.886      0.381     -16.065      41.219
# x32            4.2048      4.902      0.858      0.396      -5.688      14.098
# x33            1.6216      1.898      0.854      0.398      -2.209       5.452
# x34            1.6341      1.772      0.922      0.362      -1.941       5.209
# x35           11.3094     12.707      0.890      0.379     -14.335      36.954
# x36            8.0332      9.273      0.866      0.391     -10.681      26.747
# x37            2.3417      2.835      0.826      0.414      -3.380       8.064
# x38            1.8715      2.366      0.791      0.433      -2.904       6.647
# x39            4.5984      5.194      0.885      0.381      -5.884      15.081
# x40            2.5389      2.786      0.911      0.367      -3.084       8.162
# x41            1.1080      1.113      0.996      0.325      -1.138       3.354
# x42            1.2770      1.374      0.929      0.358      -1.496       4.050
# x43           11.2597     12.772      0.882      0.383     -14.516      37.035
# x44            5.7326      6.577      0.872      0.388      -7.540      19.005
# x45            2.4564      2.944      0.834      0.409      -3.485       8.398
# x46            2.1548      2.537      0.849      0.401      -2.965       7.275
# x47           13.1161     15.294      0.858      0.396     -17.748      43.980
# x48            4.6456      5.214      0.891      0.378      -5.877      15.168
# x49            1.3410      1.663      0.806      0.425      -2.016       4.698
# x50            1.2611      1.504      0.839      0.406      -1.773       4.295
# ==============================================================================
# Omnibus:                        2.675   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.262   Jarque-Bera (JB):                2.009
# Skew:                           0.291   Prob(JB):                        0.366
# Kurtosis:                       3.423   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model1 = smf.ols(
    'Y ~ x1 +'\
        'x2 +'\
        'x3 +'\
        'x4 +'\
        'x5 +'\
        'x6 +'\
        'x7 +'\
        'x8 +'\
        'x9 +'\
        'x10 +'\
        'x11 +'\
        'x12 +'\
        'x13 +'\
        'x14 +'\
        'x15 +'\
        'x16 +'\
        'x17 +'\
        'x18 +'\
        'x19 +'\
        'x20 +'\
        'x21 +'\
        'x22 +'\
        'x23 +'\
        'x24 +'\
        'x25 +'\
        'x26 +'\
        'x27 +'\
        'x28 +'\
        'x29 +'\
        'x30 +'\
        'x31 +'\
        'x32 +'\
        'x33 +'\
        'x34 +'\
        'x35 +'\
        'x36 +'\
        'x38 +'\
        'x39 +'\
        'x40 +'\
        'x41 +'\
        'x42 +'\
        'x43 +'\
        'x44 +'\
        'x45 +'\
        'x46 +'\
        'x47 +'\
        'x48 +'\
        'x49 +'\
        'x50'
    , data = X
)
fitted = model1.fit()
print (fitted.summary())

# %% [markdown]
# ### Can see collinearity warning, let's put away some variables

# %%
x_cols = [
    'x1',
    'x2',
    'x3',
    'x4', 
    'x5',  
    #'x6', 
    #'x7',
    'x8',
    'x9',
    'x10',
    'x11', 
    'x12',
    'x13',
    #'x14',
    #'x15',
    'x16',
    #'x17',
    'x18',
    'x19',
    #'x20',
    'x21',
    'x22', 
    #'x23',
    #'x24',
    #'x25',
    'x26',
    #'x27', 
    'x28',
    'x29',
    #'x30',
    #'x31', 
    #'x32', 
    'x33', 
    'x34',
    'x35',
    # 'x36', 
    # 'x37', 
     'x38', 
    # 'x39', 
     'x40',
     'x41', 
     'x42', 
     'x43', 
     'x44',
#    'x45',      
#    'x46', 
    'x47',     
    'x48', 
#    'x49', 
#    'x50'
]
X1 = X.loc[:,X.columns.isin(x_cols)]

# %%
model1 = sm.OLS(Y,sm.add_constant(X1))
fitted = model1.fit()
print (fitted.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     LIFETIME_BEDVALUE_mean   R-squared:                       0.750
# Model:                                OLS   Adj. R-squared:                  0.629
# Method:                     Least Squares   F-statistic:                     6.188
# Date:                    Mon, 02 May 2022   Prob (F-statistic):           7.82e-10
# Time:                            11:51:15   Log-Likelihood:                -67.564
# No. Observations:                      93   AIC:                             197.1
# Df Residuals:                          62   BIC:                             275.6
# Df Model:                              30
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.292e-15      0.064   5.18e-14      1.000      -0.127       0.127
# x1             0.0594      0.109      0.543      0.589      -0.159       0.278
# x2             0.1862      0.110      1.689      0.096      -0.034       0.407
# x3            -0.1451      0.081     -1.788      0.079      -0.307       0.017
# x4            -0.0442      0.079     -0.560      0.577      -0.202       0.113
# x5             0.1119      0.069      1.612      0.112      -0.027       0.251
# x8            -0.0697      0.081     -0.861      0.393      -0.231       0.092
# x9             0.0816      0.072      1.131      0.262      -0.063       0.226
# x10            0.0309      0.079      0.393      0.696      -0.126       0.188
# x11           -0.0857      0.081     -1.064      0.292      -0.247       0.075
# x12            0.0767      0.078      0.983      0.329      -0.079       0.233
# x13           -0.0860      0.079     -1.084      0.283      -0.245       0.073
# x16           -0.0707      0.078     -0.911      0.366      -0.226       0.084
# x18           -0.1444      0.078     -1.852      0.069      -0.300       0.011
# x19            0.0787      0.076      1.037      0.304      -0.073       0.230
# x21           -0.0681      0.075     -0.902      0.370      -0.219       0.083
# x22            0.0778      0.083      0.943      0.350      -0.087       0.243
# x26            0.1242      0.074      1.681      0.098      -0.023       0.272
# x28           -0.1742      0.074     -2.363      0.021      -0.322      -0.027
# x29            0.1429      0.075      1.893      0.063      -0.008       0.294
# x33           -0.0579      0.081     -0.715      0.477      -0.220       0.104
# x34            0.1029      0.089      1.150      0.254      -0.076       0.282
# x35            0.2629      0.117      2.256      0.028       0.030       0.496
# x38           -0.1250      0.077     -1.615      0.111      -0.280       0.030
# x40            0.0917      0.077      1.190      0.239      -0.062       0.246
# x41            0.1403      0.073      1.924      0.059      -0.005       0.286
# x42            0.0760      0.073      1.036      0.304      -0.071       0.223
# x43            0.0077      0.093      0.083      0.934      -0.178       0.194
# x44            0.0364      0.080      0.455      0.651      -0.123       0.196
# x47           -0.2890      0.111     -2.597      0.012      -0.512      -0.067
# x48            0.1419      0.083      1.705      0.093      -0.024       0.308
# ==============================================================================
# Omnibus:                        3.468   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.177   Jarque-Bera (JB):                2.772
# Skew:                           0.343   Prob(JB):                        0.250
# Kurtosis:                       3.495   Cond. No.                         5.03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Prob (F-statistic) =  7.82e-10 => This model makes at least some sense and the hypothesis that all coefficients before x are equal to zero is rejected. Let's check the residuals for heteroscedasticity using the Broisch-Pagan test.

# %%
print ('Breusch-Pagan test: p=%f' % sms.het_breuschpagan(fitted.resid, fitted.model.exog)[1])
# Out:
# Breusch-Pagan test: p=0.437888

# %% [markdown]
# ### Errors are homoscedastic, which means  the significance of features determined correctly.

# %%
plt.rcParams["figure.figsize"] = (16,7)
plt.subplot(121)
sc.stats.probplot(fitted.resid, dist="norm", plot=plt)
plt.subplot(122)
np.log(fitted.resid).plot.hist()
plt.xlabel('Residuals', fontsize=14)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(6,5)})

for col in X:
    sns.scatterplot(X[col],fitted.resid)
    plt.xlabel(col, fontsize=14)
    plt.ylabel('Residuals', fontsize=14)
    plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### On screens above we can see couple of outliers, let's see them

# %%
X['x5'].idxmax()
# Out:
# 41

# %%
X['x6'].idxmax()
# Out:
# 48

# %%
X['x11'].idxmax()
# Out:
# 77

# %%
X['x13'].idxmax()
# Out:
# 86

# %%
X['x16'].idxmax()
# Out:
# 29

# %%
X['x18'].idxmax()
# Out:
# 77

# %% [markdown]
# ### Let's do another analysis:
# ### Let's build a graph of the so-called "influence" points. Since the regression tends to reconfigure for atypical observations (lying far from the main cloud). Let's see if there are such points in our data.
# ### The squares of the residuals for each of the observations are plotted along the horizontal axis, and the "influence" of the observation along the vertical axis. The larger the vertical value, the more this observation affects the regression equation

# %%
plot_leverage_resid2(fitted)
plt.show()

# %% [markdown]
# ### Nothing prevents us from looking at some of the points (observations) that lie relatively far from the main cloud.

# %%
outliers = [41,48,77,86,29,0,43,31,63,67,35,16]
#scale.inverse_transform(X.loc[outliers])
#pd.DataFrame(scale.inverse_transform(X.loc[outliers]),columns = X.loc[outliers].columns)

# %%
X2 = X1.drop(X.index[outliers])
Y2 = Y.drop(Y.index[outliers])

# %%
model3 = sm.OLS(Y2,sm.add_constant(X2))
fitted = model3.fit()
print (fitted.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     LIFETIME_BEDVALUE_mean   R-squared:                       0.858
# Model:                                OLS   Adj. R-squared:                  0.772
# Method:                     Least Squares   F-statistic:                     10.04
# Date:                    Mon, 02 May 2022   Prob (F-statistic):           1.32e-12
# Time:                            11:53:10   Log-Likelihood:                -26.450
# No. Observations:                      81   AIC:                             114.9
# Df Residuals:                          50   BIC:                             189.1
# Df Model:                              30
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0162      0.050     -0.324      0.748      -0.116       0.084
# x1             0.2099      0.081      2.583      0.013       0.047       0.373
# x2             0.0489      0.092      0.529      0.599      -0.137       0.235
# x3            -0.0768      0.064     -1.205      0.234      -0.205       0.051
# x4            -0.0468      0.063     -0.740      0.463      -0.174       0.080
# x5             0.1745      0.087      2.009      0.050    7.24e-05       0.349
# x8             0.0223      0.063      0.354      0.725      -0.104       0.149
# x9             0.0400      0.054      0.744      0.461      -0.068       0.148
# x10            0.0292      0.059      0.497      0.621      -0.089       0.147
# x11           -0.0993      0.066     -1.501      0.140      -0.232       0.034
# x12            0.0230      0.060      0.380      0.706      -0.099       0.144
# x13            0.0083      0.067      0.123      0.902      -0.126       0.143
# x16            0.0222      0.077      0.286      0.776      -0.133       0.178
# x18            0.0176      0.082      0.215      0.831      -0.147       0.182
# x19            0.1079      0.060      1.791      0.079      -0.013       0.229
# x21           -0.0765      0.059     -1.303      0.199      -0.194       0.041
# x22            0.0025      0.062      0.040      0.969      -0.122       0.127
# x26            0.1834      0.056      3.300      0.002       0.072       0.295
# x28           -0.1106      0.056     -1.981      0.053      -0.223       0.002
# x29            0.1784      0.055      3.269      0.002       0.069       0.288
# x33            0.0209      0.060      0.351      0.727      -0.099       0.141
# x34           -0.0327      0.069     -0.474      0.637      -0.171       0.106
# x35            0.2001      0.092      2.165      0.035       0.014       0.386
# x38           -0.1068      0.059     -1.805      0.077      -0.226       0.012
# x40            0.0846      0.058      1.453      0.152      -0.032       0.202
# x41            0.1123      0.059      1.889      0.065      -0.007       0.232
# x42            0.0068      0.053      0.127      0.899      -0.100       0.113
# x43            0.1415      0.073      1.936      0.059      -0.005       0.288
# x44            0.0620      0.060      1.030      0.308      -0.059       0.183
# x47           -0.2515      0.082     -3.063      0.004      -0.416      -0.087
# x48           -0.0117      0.068     -0.171      0.865      -0.149       0.125
# ==============================================================================
# Omnibus:                        2.062   Durbin-Watson:                   2.304
# Prob(Omnibus):                  0.357   Jarque-Bera (JB):                2.055
# Skew:                           0.364   Prob(JB):                        0.358
# Kurtosis:                       2.721   Cond. No.                         6.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.rcParams["figure.figsize"] = (16,7)
plt.subplot(121)
sc.stats.probplot(fitted.resid, dist="norm", plot=plt)
plt.subplot(122)
np.log(fitted.resid).plot.hist()
plt.xlabel('Residuals', fontsize=14)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plot_leverage_resid2(fitted)
plt.show()

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(6,5)})

for col in X2:
    sns.scatterplot(X2[col],fitted.resid)
    plt.xlabel(col, fontsize=14)
    plt.ylabel('Residuals', fontsize=14)
    plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Also note that in the previous model we have insignificant variables: Intercept and others, we will remove them from the model.
# ## Model #4: Model without part of the observations (atypical) and without non-significant variables

# %%
X3= X2.drop(['x2','x3','x4','x8','x9','x10','x11','x12','x13','x16','x18','x21','x22','x33','x34','x40','x42','x44','x48'],axis=1)
Y3 = Y2

# %%
model4 = sm.OLS(Y3,X3)
fitted = model4.fit()
print (fitted.summary())

# %%
print ('Breusch-Pagan test: p=%f' % sms.het_breuschpagan(fitted.resid, fitted.model.exog)[1])
# Out:
# Breusch-Pagan test: p=0.793016

# %%
plt.rcParams["figure.figsize"] = (16,7)
plt.subplot(121)
sc.stats.probplot(fitted.resid, dist="norm", plot=plt)
plt.subplot(122)
np.log(fitted.resid).plot.hist()
plt.xlabel('Residuals', fontsize=14)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(6,5)})

for col in X3:
    sns.scatterplot(X3[col],fitted.resid)
    plt.xlabel(col, fontsize=14)
    plt.ylabel('Residuals', fontsize=14)
    plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
coefs_list=pd.DataFrame(fitted.params)

# %%
cols_dict_1 = {}
test = cols_dict
for key, value in test.items():
    try_1 = value
    try_1=try_1.replace('ACQ_BEDVALUE', 'Monetary percent (avg)')
    try_1=try_1.replace('CUSTOMER_ID', 'Customer Volume percent')
    cols_dict.update({key:try_1})

# %%
for key, value in cols_dict.items():
    for i in coefs_list.index:   
        if coefs_list.loc[i].name==key:
            coefs_list = coefs_list.rename(index = {key : value})
        else: 
            pass

# %%
#features.index
features = coefs_list
coef = coefs_list.iloc[:,0]

features = features[coef != 0.0]
coef = coef[coef != 0]
coef_idx = np.argsort(coef)

plt.figure(figsize=(8, 10))
plt.title("Coefficients")
coef_num = range(len(coef))
plt.barh(coef_num, coef[coef_idx], color="r", align="center")

plt.yticks(coef_num, features.index[coef_idx])
plt.ylim([-1, len(features)])

plt.show()

# %% [markdown]
# ## Takeaways:
# ### 1) We now account for almost 79% of the variation in the target variable. This is a good result.
# ### 2) The accuracy criterion was chosen R^2. From it, "Important" variables for the model depicted above are "Not important" - the rest
# ### 3) Consider further exploration of atypical observations, removed prior model #3
# ### 4) Consider increasing the number of observations, in the final model we have around 80 rows of data and 11 columns. While there are no strict rules on data volumes, a rule of thumb of having 10 rows of data per 1 column
